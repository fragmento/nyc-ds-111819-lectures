# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'wmkiJaufttIjsNPsauGcnA'
api_key = 'j-IeTwaU034Qp8wVNBk6JqIQK4lC8vjUt-SHL1bFZ1FsNNjo7CAm4SPs3VvtQtD2g1iHIEA3F-XOmbL0LmCWIEIYSFJCYScRtOpm5gaED8nH1o2jEjJUPqRoYk_pXXYx'

# %%
#client_id = 'bVX1Jsfp4dkIOqw5HOVplg' #Your client ID goes here (as a string)
#api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx' #Your api key goes here (as a string)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = ''

#where do you want to perform this search
location = 'Bedford-Stuyvesant'

# what is your other parameter you want to search against
price = '2'

# %%
url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'price' : price
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "93AmVm0EksvVCR2MmIpBfg", "alias": "bowery-yoga-new-york", "name": "Bowery Yoga", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Pj9DgtQHXk0jb7WANILDuQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bowery-yoga-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA", "review_count": 8, "categories": [{"alias": "yoga", "title": "Yoga"}, {"alias": "massage", "title": "Massage"}], "rating": 5.0, "coordinates": {"latitude": 40.7247167873211, "longitude": -73.9926418662357}, "transactions": [], "price": "$$", "location": {"address1": "302 Bowery", "address2": "Fl 3", "address3": null, "city": "New York", "zip_code": "10012", "country": "US", "state": "NY", "display_address": ["302 Bowery", "Fl 3", "New York, NY 10012"]}, "phone": "+19178850278", "display_phone": "(917) 885-0278", "distance": 6214.405949694555}, {"id": "B9P8YCOk5QjHD7dw8WXA_Q", "alias": "awakening

# %% [raw]
# response.text

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': '93AmVm0EksvVCR2MmIpBfg',
#    'alias': 'bowery-yoga-new-york',
#    'name': 'Bowery Yoga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pj9DgtQHXk0jb7WANILDuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bowery-yoga-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 8,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7247167873211,
#     'longitude': -73.9926418662357},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Bowery',
#     'address2': 'Fl 3',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Bowery', 'Fl 3', 'New York, NY 10012']},
#    'phone': '+19178850278',
#    'display_phone': '(917) 885-0278',
#    'distance': 6214.405949694555},
#   {'id': 'B9P8YCOk5QjHD7dw8WXA_Q',
#    'alias': 'awakening-ny-brooklyn-2',
#    'name': 'Awakening NY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KlwFEg4b4yUrobk-ndduSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awakening-ny-brooklyn-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 99,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723268, 'longitude': -73.950786},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '605 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491380',
#    'display_phone': '(718) 349-1380',
#    'distance': 4034.085029999166},
#   {'id': 'zUnNfTaf_sjmr-dxsFi3mA',
#    'alias': 'atmananda-yoga-sequence-new-york-10',
#    'name': 'Atmananda Yoga Sequence',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d2flt_NA5AUrKosMeV0vJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atmananda-yoga-sequence-new-york-10?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 24,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7396604, 'longitude': -73.985891},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '112 E 23rd St',
#     'address2': 'Ste 200',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 E 23rd St', 'Ste 200', 'New York, NY 10010']},
#    'phone': '+12126251511',
#    'display_phone': '(212) 625-1511',
#    'distance': 7042.9079812844775},
#   {'id': 'I4A7W1rSsWVlAtfU2xQ3ew',
#    'alias': 'jaya-yoga-east-brooklyn',
#    'name': 'Jaya Yoga East',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4n6lA1mEk4AwEAlUq-c-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaya-yoga-east-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 23,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'reflexology', 'title': 'Reflexology'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6486, 'longitude': -73.97761},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2902 Ft Hamilton Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2902 Ft Hamilton Pkwy', 'Brooklyn, NY 11218']},
#    'phone': '+19177405292',
#    'display_phone': '(917) 740-5292',
#    'distance': 5662.541943464536},
#   {'id': 'lnDnRkke4Hi-QlEnk2o8XA',
#    'alias': 'greenhouse-holistic-brooklyn',
#    'name': 'Greenhouse Holistic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/67viRRYMxf5wWNlU2TU75Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenhouse-holistic-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 189,
#    'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'saunas', 'title': 'Saunas'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71676, 'longitude': -73.95621},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '218 N 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 N 7th St', 'Brooklyn, NY 11211']},
#    'phone': '+17185993113',
#    'display_phone': '(718) 599-3113',
#    'distance': 3542.8356627053304},
#   {'id': 'piSQklM0IJGJBVi49K_WZA',
#    'alias': 'hands-on-health-brooklyn',
#    'name': 'Hands On Health',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MJnZrlhJGcxANiqq9u39zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hands-on-health-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6599, 'longitude': -73.98397},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1663 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1663 8th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19178366034',
#    'display_phone': '(917) 836-6034',
#    'distance': 5130.3533848940915},
#   {'id': '0k2gUhV6Js2MSqMXh8LgnA',
#    'alias': 'force-and-flow-new-york',
#    'name': 'Force and Flow',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t9LpOQJbLHeuIxG-WzHPBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/force-and-flow-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 9,
#    'categories': [{'alias': 'pilates', 'title': 'Pilates'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'qigong', 'title': 'Qi Gong'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7523994445801,
#     'longitude': -73.9730987548828},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10017']},
#    'phone': '+16466449743',
#    'display_phone': '(646) 644-9743',
#    'distance': 7582.659482607898},
#   {'id': 'JmvsOxnrsnwuUQIGXOeT6A',
#    'alias': 'aesthetics-by-mirelle-new-york',
#    'name': 'Aesthetics by Mirelle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gXAnpnJarkj0mlzDbjWcjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aesthetics-by-mirelle-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 67,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'waxing', 'title': 'Waxing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7098, 'longitude': -74.00806},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '80 Nassau St',
#     'address2': 'Suite 2A',
#     'address3': 'Buzzer 001, West Elevators',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Nassau St',
#      'Suite 2A',
#      'Buzzer 001, West Elevators',
#      'New York, NY 10038']},
#    'phone': '+15163831336',
#    'display_phone': '(516) 383-1336',
#    'distance': 6480.47149053597},
#   {'id': 'pwJyYxTwRT9j4E5i1JpyBQ',
#    'alias': 'crystal-lization-new-york',
#    'name': 'Crystal Lization',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-J95zMOIVtch7qEBVSJKQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crystal-lization-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7397755094911,
#     'longitude': -73.9834659640015},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '227 E 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 E 24th St', 'New York, NY 10010']},
#    'phone': '+16465488067',
#    'display_phone': '(646) 548-8067',
#    'distance': 6933.9747220374475},
#   {'id': 'SNPooW7pbsGBz_YS1Pscsw',
#    'alias': 'elements-massage-montclair-montclair',
#    'name': 'Elements Massage - Montclair',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4wLoOQTNw3C6gkCMFnza4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elements-massage-montclair-montclair?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 75,
#    'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8144631, 'longitude': -74.218524},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '496 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Montclair',
#     'zip_code': '07042',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['496 Bloomfield Ave', 'Montclair, NJ 07042']},
#    'phone': '+19735091119',
#    'display_phone': '(973) 509-1119',
#    'distance': 27587.263201553014},
#   {'id': '78PxwtwZLuGac71kuGyCpQ',
#    'alias': 'madison-healing-arts-new-york-2',
#    'name': 'Madison Healing Arts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GI6B1ylPozMqn9Lt1J_jrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madison-healing-arts-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 81,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75144, 'longitude': -73.98046},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '280 Madison Ave',
#     'address2': 'Ste 508',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Madison Ave', 'Ste 508', 'New York, NY 10016']},
#    'phone': '+16464818722',
#    'display_phone': '(646) 481-8722',
#    'distance': 7908.683128760308},
#   {'id': 'x0cHJYb1j3CweZMU9YLQnA',
#    'alias': 'gibney-dance-new-york-2',
#    'name': 'Gibney Dance',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qZ29rD0fQCjA_BI1CIF2rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gibney-dance-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'dancestudio', 'title': 'Dance Studios'},
#     {'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71436, 'longitude': -74.00588},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '280 Broadway',
#     'address2': '',
#     'address3': 'Entrance at 53A Chambers',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Broadway',
#      'Entrance at 53A Chambers',
#      'New York, NY 10007']},
#    'phone': '+16468376809',
#    'display_phone': '(646) 837-6809',
#    'distance': 6524.947595337573},
#   {'id': 'PFx3q9ScrRsFhyfJo-x9KQ',
#    'alias': 'rhemedy-by-rhed-therapeutic-massage-new-york-3',
#    'name': 'Rhemedy By Rhed Therapeutic Massage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zb0fH5bn2nGEkWjwLm9DDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rhemedy-by-rhed-therapeutic-massage-new-york-3?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 118,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738413, 'longitude': -74.001718},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '230 W 13th St',
#     'address2': '',
#     'address3': 'Buzzer D Lower Level',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 W 13th St',
#      'Buzzer D Lower Level',
#      'New York, NY 10011']},
#    'phone': '+13472840086',
#    'display_phone': '(347) 284-0086',
#    'distance': 7809.4139326530985},
#   {'id': 'rw3uCeZBVg6L_AVc_NxacQ',
#    'alias': 'buri-spa-new-york',
#    'name': 'Buri Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m4ETIDQvKv3dZC_ePY8Muw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buri-spa-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 42,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7481614, 'longitude': -73.9872958},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '39 W 32nd St',
#     'address2': 'Ste 303',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 32nd St', 'Ste 303', 'New York, NY 10001']},
#    'phone': '+19294760118',
#    'display_phone': '(929) 476-0118',
#    'distance': 7887.420039933388},
#   {'id': 'i1ktAfyO-PN0DMgQeqZj6A',
#    'alias': 'citytouch-licensed-massage-therapy-new-york-5',
#    'name': 'CityTouch Licensed Massage Therapy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H8_-AvsG4bCSvuX3mDYr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citytouch-licensed-massage-therapy-new-york-5?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 176,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'reflexology', 'title': 'Reflexology'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7463320587553,
#     'longitude': -73.9928632510285},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '153 West 27 St',
#     'address2': 'Ste 404',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 West 27 St', 'Ste 404', 'New York, NY 10001']},
#    'phone': '+19175622285',
#    'display_phone': '(917) 562-2285',
#    'distance': 7988.675820562291}],
#  'total': 19,
#  'region': {'center': {'longitude': -73.93627166748047,
#    'latitude': 40.68869726813401}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': '93AmVm0EksvVCR2MmIpBfg',
#    'alias': 'bowery-yoga-new-york',
#    'name': 'Bowery Yoga',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pj9DgtQHXk0jb7WANILDuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bowery-yoga-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 8,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7247167873211,
#     'longitude': -73.9926418662357},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '302 Bowery',
#     'address2': 'Fl 3',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['302 Bowery', 'Fl 3', 'New York, NY 10012']},
#    'phone': '+19178850278',
#    'display_phone': '(917) 885-0278',
#    'distance': 6214.405949694555},
#   {'id': 'B9P8YCOk5QjHD7dw8WXA_Q',
#    'alias': 'awakening-ny-brooklyn-2',
#    'name': 'Awakening NY',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KlwFEg4b4yUrobk-ndduSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/awakening-ny-brooklyn-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 99,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.723268, 'longitude': -73.950786},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '605 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['605 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183491380',
#    'display_phone': '(718) 349-1380',
#    'distance': 4034.085029999166},
#   {'id': 'zUnNfTaf_sjmr-dxsFi3mA',
#    'alias': 'atmananda-yoga-sequence-new-york-10',
#    'name': 'Atmananda Yoga Sequence',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d2flt_NA5AUrKosMeV0vJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atmananda-yoga-sequence-new-york-10?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 24,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7396604, 'longitude': -73.985891},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '112 E 23rd St',
#     'address2': 'Ste 200',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 E 23rd St', 'Ste 200', 'New York, NY 10010']},
#    'phone': '+12126251511',
#    'display_phone': '(212) 625-1511',
#    'distance': 7042.9079812844775},
#   {'id': 'I4A7W1rSsWVlAtfU2xQ3ew',
#    'alias': 'jaya-yoga-east-brooklyn',
#    'name': 'Jaya Yoga East',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4n6lA1mEk4AwEAlUq-c-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaya-yoga-east-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 23,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'reflexology', 'title': 'Reflexology'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6486, 'longitude': -73.97761},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2902 Ft Hamilton Pkwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2902 Ft Hamilton Pkwy', 'Brooklyn, NY 11218']},
#    'phone': '+19177405292',
#    'display_phone': '(917) 740-5292',
#    'distance': 5662.541943464536},
#   {'id': 'lnDnRkke4Hi-QlEnk2o8XA',
#    'alias': 'greenhouse-holistic-brooklyn',
#    'name': 'Greenhouse Holistic',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/67viRRYMxf5wWNlU2TU75Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/greenhouse-holistic-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 189,
#    'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'saunas', 'title': 'Saunas'},
#     {'alias': 'spas', 'title': 'Day Spas'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71676, 'longitude': -73.95621},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '218 N 7th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218 N 7th St', 'Brooklyn, NY 11211']},
#    'phone': '+17185993113',
#    'display_phone': '(718) 599-3113',
#    'distance': 3542.8356627053304},
#   {'id': 'piSQklM0IJGJBVi49K_WZA',
#    'alias': 'hands-on-health-brooklyn',
#    'name': 'Hands On Health',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MJnZrlhJGcxANiqq9u39zg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hands-on-health-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.6599, 'longitude': -73.98397},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1663 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1663 8th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+19178366034',
#    'display_phone': '(917) 836-6034',
#    'distance': 5130.3533848940915},
#   {'id': '0k2gUhV6Js2MSqMXh8LgnA',
#    'alias': 'force-and-flow-new-york',
#    'name': 'Force and Flow',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t9LpOQJbLHeuIxG-WzHPBw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/force-and-flow-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 9,
#    'categories': [{'alias': 'pilates', 'title': 'Pilates'},
#     {'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'qigong', 'title': 'Qi Gong'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7523994445801,
#     'longitude': -73.9730987548828},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['New York, NY 10017']},
#    'phone': '+16466449743',
#    'display_phone': '(646) 644-9743',
#    'distance': 7582.659482607898},
#   {'id': 'JmvsOxnrsnwuUQIGXOeT6A',
#    'alias': 'aesthetics-by-mirelle-new-york',
#    'name': 'Aesthetics by Mirelle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gXAnpnJarkj0mlzDbjWcjA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aesthetics-by-mirelle-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 67,
#    'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#     {'alias': 'yoga', 'title': 'Yoga'},
#     {'alias': 'waxing', 'title': 'Waxing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7098, 'longitude': -74.00806},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '80 Nassau St',
#     'address2': 'Suite 2A',
#     'address3': 'Buzzer 001, West Elevators',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['80 Nassau St',
#      'Suite 2A',
#      'Buzzer 001, West Elevators',
#      'New York, NY 10038']},
#    'phone': '+15163831336',
#    'display_phone': '(516) 383-1336',
#    'distance': 6480.47149053597},
#   {'id': 'pwJyYxTwRT9j4E5i1JpyBQ',
#    'alias': 'crystal-lization-new-york',
#    'name': 'Crystal Lization',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-J95zMOIVtch7qEBVSJKQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crystal-lization-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7397755094911,
#     'longitude': -73.9834659640015},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '227 E 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['227 E 24th St', 'New York, NY 10010']},
#    'phone': '+16465488067',
#    'display_phone': '(646) 548-8067',
#    'distance': 6933.9747220374475},
#   {'id': 'SNPooW7pbsGBz_YS1Pscsw',
#    'alias': 'elements-massage-montclair-montclair',
#    'name': 'Elements Massage - Montclair',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4wLoOQTNw3C6gkCMFnza4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elements-massage-montclair-montclair?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 75,
#    'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'massage', 'title': 'Massage'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8144631, 'longitude': -74.218524},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '496 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Montclair',
#     'zip_code': '07042',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['496 Bloomfield Ave', 'Montclair, NJ 07042']},
#    'phone': '+19735091119',
#    'display_phone': '(973) 509-1119',
#    'distance': 27587.263201553014},
#   {'id': '78PxwtwZLuGac71kuGyCpQ',
#    'alias': 'madison-healing-arts-new-york-2',
#    'name': 'Madison Healing Arts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GI6B1ylPozMqn9Lt1J_jrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/madison-healing-arts-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 81,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'reflexology', 'title': 'Reflexology'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.75144, 'longitude': -73.98046},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '280 Madison Ave',
#     'address2': 'Ste 508',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Madison Ave', 'Ste 508', 'New York, NY 10016']},
#    'phone': '+16464818722',
#    'display_phone': '(646) 481-8722',
#    'distance': 7908.683128760308},
#   {'id': 'x0cHJYb1j3CweZMU9YLQnA',
#    'alias': 'gibney-dance-new-york-2',
#    'name': 'Gibney Dance',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qZ29rD0fQCjA_BI1CIF2rA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gibney-dance-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 7,
#    'categories': [{'alias': 'dancestudio', 'title': 'Dance Studios'},
#     {'alias': 'galleries', 'title': 'Art Galleries'},
#     {'alias': 'theater', 'title': 'Performing Arts'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.71436, 'longitude': -74.00588},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '280 Broadway',
#     'address2': '',
#     'address3': 'Entrance at 53A Chambers',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Broadway',
#      'Entrance at 53A Chambers',
#      'New York, NY 10007']},
#    'phone': '+16468376809',
#    'display_phone': '(646) 837-6809',
#    'distance': 6524.947595337573},
#   {'id': 'PFx3q9ScrRsFhyfJo-x9KQ',
#    'alias': 'rhemedy-by-rhed-therapeutic-massage-new-york-3',
#    'name': 'Rhemedy By Rhed Therapeutic Massage',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zb0fH5bn2nGEkWjwLm9DDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rhemedy-by-rhed-therapeutic-massage-new-york-3?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 118,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'reiki', 'title': 'Reiki'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738413, 'longitude': -74.001718},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '230 W 13th St',
#     'address2': '',
#     'address3': 'Buzzer D Lower Level',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['230 W 13th St',
#      'Buzzer D Lower Level',
#      'New York, NY 10011']},
#    'phone': '+13472840086',
#    'display_phone': '(347) 284-0086',
#    'distance': 7809.4139326530985},
#   {'id': 'rw3uCeZBVg6L_AVc_NxacQ',
#    'alias': 'buri-spa-new-york',
#    'name': 'Buri Spa',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m4ETIDQvKv3dZC_ePY8Muw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buri-spa-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 42,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7481614, 'longitude': -73.9872958},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '39 W 32nd St',
#     'address2': 'Ste 303',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 32nd St', 'Ste 303', 'New York, NY 10001']},
#    'phone': '+19294760118',
#    'display_phone': '(929) 476-0118',
#    'distance': 7887.420039933388},
#   {'id': 'i1ktAfyO-PN0DMgQeqZj6A',
#    'alias': 'citytouch-licensed-massage-therapy-new-york-5',
#    'name': 'CityTouch Licensed Massage Therapy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H8_-AvsG4bCSvuX3mDYr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/citytouch-licensed-massage-therapy-new-york-5?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#    'review_count': 176,
#    'categories': [{'alias': 'massage', 'title': 'Massage'},
#     {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#     {'alias': 'reflexology', 'title': 'Reflexology'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7463320587553,
#     'longitude': -73.9928632510285},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '153 West 27 St',
#     'address2': 'Ste 404',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['153 West 27 St', 'Ste 404', 'New York, NY 10001']},
#    'phone': '+19175622285',
#    'display_phone': '(917) 562-2285',
#    'distance': 7988.675820562291}],
#  'total': 19,
#  'region': {'center': {'longitude': -73.93627166748047,
#    'latitude': 40.68869726813401}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
a
# Out:
# businesses
# <class 'list'>
#
#
# total
# <class 'int'>
#
#
# region
# <class 'dict'>

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['region']
# Out:
# {'center': {'longitude': -73.93627166748047, 'latitude': 40.68869726813401}}

# %%
data['total']
# Out:
# 19

# %%
type(data)
# Out:
# dict

# %%
data['businesses']
# Out:
# [{'id': '93AmVm0EksvVCR2MmIpBfg',
#   'alias': 'bowery-yoga-new-york',
#   'name': 'Bowery Yoga',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pj9DgtQHXk0jb7WANILDuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bowery-yoga-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 8,
#   'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'massage', 'title': 'Massage'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7247167873211,
#    'longitude': -73.9926418662357},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '302 Bowery',
#    'address2': 'Fl 3',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['302 Bowery', 'Fl 3', 'New York, NY 10012']},
#   'phone': '+19178850278',
#   'display_phone': '(917) 885-0278',
#   'distance': 6214.405949694555},
#  {'id': 'B9P8YCOk5QjHD7dw8WXA_Q',
#   'alias': 'awakening-ny-brooklyn-2',
#   'name': 'Awakening NY',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KlwFEg4b4yUrobk-ndduSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/awakening-ny-brooklyn-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 99,
#   'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.723268, 'longitude': -73.950786},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '605 Manhattan Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['605 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17183491380',
#   'display_phone': '(718) 349-1380',
#   'distance': 4034.085029999166},
#  {'id': 'zUnNfTaf_sjmr-dxsFi3mA',
#   'alias': 'atmananda-yoga-sequence-new-york-10',
#   'name': 'Atmananda Yoga Sequence',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d2flt_NA5AUrKosMeV0vJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atmananda-yoga-sequence-new-york-10?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 24,
#   'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'massage', 'title': 'Massage'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7396604, 'longitude': -73.985891},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '112 E 23rd St',
#    'address2': 'Ste 200',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['112 E 23rd St', 'Ste 200', 'New York, NY 10010']},
#   'phone': '+12126251511',
#   'display_phone': '(212) 625-1511',
#   'distance': 7042.9079812844775},
#  {'id': 'I4A7W1rSsWVlAtfU2xQ3ew',
#   'alias': 'jaya-yoga-east-brooklyn',
#   'name': 'Jaya Yoga East',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4n6lA1mEk4AwEAlUq-c-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jaya-yoga-east-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 23,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'reflexology', 'title': 'Reflexology'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6486, 'longitude': -73.97761},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2902 Ft Hamilton Pkwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11218',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2902 Ft Hamilton Pkwy', 'Brooklyn, NY 11218']},
#   'phone': '+19177405292',
#   'display_phone': '(917) 740-5292',
#   'distance': 5662.541943464536},
#  {'id': 'lnDnRkke4Hi-QlEnk2o8XA',
#   'alias': 'greenhouse-holistic-brooklyn',
#   'name': 'Greenhouse Holistic',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/67viRRYMxf5wWNlU2TU75Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/greenhouse-holistic-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 189,
#   'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#    {'alias': 'saunas', 'title': 'Saunas'},
#    {'alias': 'spas', 'title': 'Day Spas'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71676, 'longitude': -73.95621},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '218 N 7th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['218 N 7th St', 'Brooklyn, NY 11211']},
#   'phone': '+17185993113',
#   'display_phone': '(718) 599-3113',
#   'distance': 3542.8356627053304},
#  {'id': 'piSQklM0IJGJBVi49K_WZA',
#   'alias': 'hands-on-health-brooklyn',
#   'name': 'Hands On Health',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MJnZrlhJGcxANiqq9u39zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hands-on-health-brooklyn?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 7,
#   'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'healthtrainers', 'title': 'Trainers'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.6599, 'longitude': -73.98397},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1663 8th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1663 8th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+19178366034',
#   'display_phone': '(917) 836-6034',
#   'distance': 5130.3533848940915},
#  {'id': '0k2gUhV6Js2MSqMXh8LgnA',
#   'alias': 'force-and-flow-new-york',
#   'name': 'Force and Flow',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/t9LpOQJbLHeuIxG-WzHPBw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/force-and-flow-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 9,
#   'categories': [{'alias': 'pilates', 'title': 'Pilates'},
#    {'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'qigong', 'title': 'Qi Gong'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7523994445801,
#    'longitude': -73.9730987548828},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10017',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['New York, NY 10017']},
#   'phone': '+16466449743',
#   'display_phone': '(646) 644-9743',
#   'distance': 7582.659482607898},
#  {'id': 'JmvsOxnrsnwuUQIGXOeT6A',
#   'alias': 'aesthetics-by-mirelle-new-york',
#   'name': 'Aesthetics by Mirelle',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gXAnpnJarkj0mlzDbjWcjA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aesthetics-by-mirelle-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 67,
#   'categories': [{'alias': 'skincare', 'title': 'Skin Care'},
#    {'alias': 'yoga', 'title': 'Yoga'},
#    {'alias': 'waxing', 'title': 'Waxing'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7098, 'longitude': -74.00806},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '80 Nassau St',
#    'address2': 'Suite 2A',
#    'address3': 'Buzzer 001, West Elevators',
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['80 Nassau St',
#     'Suite 2A',
#     'Buzzer 001, West Elevators',
#     'New York, NY 10038']},
#   'phone': '+15163831336',
#   'display_phone': '(516) 383-1336',
#   'distance': 6480.47149053597},
#  {'id': 'pwJyYxTwRT9j4E5i1JpyBQ',
#   'alias': 'crystal-lization-new-york',
#   'name': 'Crystal Lization',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-J95zMOIVtch7qEBVSJKQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crystal-lization-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 7,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'reflexology', 'title': 'Reflexology'},
#    {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7397755094911,
#    'longitude': -73.9834659640015},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '227 E 24th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10010',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['227 E 24th St', 'New York, NY 10010']},
#   'phone': '+16465488067',
#   'display_phone': '(646) 548-8067',
#   'distance': 6933.9747220374475},
#  {'id': 'SNPooW7pbsGBz_YS1Pscsw',
#   'alias': 'elements-massage-montclair-montclair',
#   'name': 'Elements Massage - Montclair',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4wLoOQTNw3C6gkCMFnza4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/elements-massage-montclair-montclair?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 75,
#   'categories': [{'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#    {'alias': 'massage', 'title': 'Massage'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.8144631, 'longitude': -74.218524},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '496 Bloomfield Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Montclair',
#    'zip_code': '07042',
#    'country': 'US',
#    'state': 'NJ',
#    'display_address': ['496 Bloomfield Ave', 'Montclair, NJ 07042']},
#   'phone': '+19735091119',
#   'display_phone': '(973) 509-1119',
#   'distance': 27587.263201553014},
#  {'id': '78PxwtwZLuGac71kuGyCpQ',
#   'alias': 'madison-healing-arts-new-york-2',
#   'name': 'Madison Healing Arts',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GI6B1ylPozMqn9Lt1J_jrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/madison-healing-arts-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 81,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'reflexology', 'title': 'Reflexology'},
#    {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.75144, 'longitude': -73.98046},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '280 Madison Ave',
#    'address2': 'Ste 508',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['280 Madison Ave', 'Ste 508', 'New York, NY 10016']},
#   'phone': '+16464818722',
#   'display_phone': '(646) 481-8722',
#   'distance': 7908.683128760308},
#  {'id': 'x0cHJYb1j3CweZMU9YLQnA',
#   'alias': 'gibney-dance-new-york-2',
#   'name': 'Gibney Dance',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qZ29rD0fQCjA_BI1CIF2rA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gibney-dance-new-york-2?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 7,
#   'categories': [{'alias': 'dancestudio', 'title': 'Dance Studios'},
#    {'alias': 'galleries', 'title': 'Art Galleries'},
#    {'alias': 'theater', 'title': 'Performing Arts'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.71436, 'longitude': -74.00588},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '280 Broadway',
#    'address2': '',
#    'address3': 'Entrance at 53A Chambers',
#    'city': 'New York',
#    'zip_code': '10007',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['280 Broadway',
#     'Entrance at 53A Chambers',
#     'New York, NY 10007']},
#   'phone': '+16468376809',
#   'display_phone': '(646) 837-6809',
#   'distance': 6524.947595337573},
#  {'id': 'PFx3q9ScrRsFhyfJo-x9KQ',
#   'alias': 'rhemedy-by-rhed-therapeutic-massage-new-york-3',
#   'name': 'Rhemedy By Rhed Therapeutic Massage',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zb0fH5bn2nGEkWjwLm9DDw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rhemedy-by-rhed-therapeutic-massage-new-york-3?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 118,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#    {'alias': 'reiki', 'title': 'Reiki'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.738413, 'longitude': -74.001718},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '230 W 13th St',
#    'address2': '',
#    'address3': 'Buzzer D Lower Level',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['230 W 13th St',
#     'Buzzer D Lower Level',
#     'New York, NY 10011']},
#   'phone': '+13472840086',
#   'display_phone': '(347) 284-0086',
#   'distance': 7809.4139326530985},
#  {'id': 'rw3uCeZBVg6L_AVc_NxacQ',
#   'alias': 'buri-spa-new-york',
#   'name': 'Buri Spa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/m4ETIDQvKv3dZC_ePY8Muw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buri-spa-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 42,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'massage_therapy', 'title': 'Massage Therapy'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7481614, 'longitude': -73.9872958},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '39 W 32nd St',
#    'address2': 'Ste 303',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['39 W 32nd St', 'Ste 303', 'New York, NY 10001']},
#   'phone': '+19294760118',
#   'display_phone': '(929) 476-0118',
#   'distance': 7887.420039933388},
#  {'id': 'i1ktAfyO-PN0DMgQeqZj6A',
#   'alias': 'citytouch-licensed-massage-therapy-new-york-5',
#   'name': 'CityTouch Licensed Massage Therapy',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/H8_-AvsG4bCSvuX3mDYr0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/citytouch-licensed-massage-therapy-new-york-5?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#   'review_count': 176,
#   'categories': [{'alias': 'massage', 'title': 'Massage'},
#    {'alias': 'massage_therapy', 'title': 'Massage Therapy'},
#    {'alias': 'reflexology', 'title': 'Reflexology'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.7463320587553,
#    'longitude': -73.9928632510285},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '153 West 27 St',
#    'address2': 'Ste 404',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['153 West 27 St', 'Ste 404', 'New York, NY 10001']},
#   'phone': '+19175622285',
#   'display_phone': '(917) 562-2285',
#   'distance': 7988.675820562291}]

# %%
data['businesses'][0]

#len(data['businesses'])
# Out:
# {'id': '93AmVm0EksvVCR2MmIpBfg',
#  'alias': 'bowery-yoga-new-york',
#  'name': 'Bowery Yoga',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Pj9DgtQHXk0jb7WANILDuQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/bowery-yoga-new-york?adjust_creative=wmkiJaufttIjsNPsauGcnA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wmkiJaufttIjsNPsauGcnA',
#  'review_count': 8,
#  'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#   {'alias': 'massage', 'title': 'Massage'}],
#  'rating': 5.0,
#  'coordinates': {'latitude': 40.7247167873211, 'longitude': -73.9926418662357},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '302 Bowery',
#   'address2': 'Fl 3',
#   'address3': None,
#   'city': 'New York',
#   'zip_code': '10012',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['302 Bowery', 'Fl 3', 'New York, NY 10012']},
#  'phone': '+19178850278',
#  'display_phone': '(917) 885-0278',
#  'distance': 6214.405949694555}

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
business = data['businesses'][-1]

# %%
biz_tuple = (business['name'], 
             ''.join(business['location']['display_address']),
             business['rating'])
biz_tuple
# Out:
# ('CityTouch Licensed Massage Therapy',
#  '153 West 27 StSte 404New York, NY 10001',
#  5.0)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(datayelp):
    # create a container to hold our parsed data
    listdata = []
    
    
    # loop through our business and parse each individual business
    for business in datayelp:
        biz_tuple = (business['name'], 
             ''.join(business['location']['display_address']),
             business['rating'])
        listdata.append(biz_tuple)
    
    # in the loop, add each individual parsed parsed business to our data container
    return listdata
    # return the container with all of the parsed results

# %%
parsed_data = parse_data(data['businesses'])

# %%
type(parsed_data)
# Out:
# list

# %%
respon
