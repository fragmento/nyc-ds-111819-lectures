# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|', index_col='user_id')

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users.columns
# Out:
# Index(['age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# create pivot
gender_user = users.pivot_table(index='occupation', columns=['gender'], fill_value=0, aggfunc='size')
gender_user
# Out:
# gender          F    M
# occupation
# administrator  36   43
# artist         13   15
# doctor          0    7
# educator       26   69
# engineer        2   65
# entertainment   2   16
# executive       3   29
# healthcare     11    5
# homemaker       6    1
# lawyer          2   10
# librarian      29   22
# marketing      10   16
# none            4    5
# other          36   69
# programmer      6   60
# retired         1   13
# salesman        3    9
# scientist       3   28
# student        60  136
# technician      1   26
# writer         19   26

# %%
users['female'] = np.where(users['gender'] == 'F',1,0)

# %%
users[['occupation','female']]
# Out:
#             occupation  female
# user_id
# 1           technician       0
# 2                other       1
# 3               writer       0
# 4           technician       0
# 5                other       1
# ...                ...     ...
# 939            student       1
# 940      administrator       0
# 941            student       0
# 942          librarian       1
# 943            student       0
#
# [943 rows x 2 columns]

# %%
gender_user['sums'] = gender_user[['F', 'M']].sum(axis=1)
gender_user.head()
# Out:
# gender          F   M  sums
# occupation
# administrator  36  43    79
# artist         13  15    28
# doctor          0   7     7
# educator       26  69    95
# engineer        2  65    67

# %%
# calculate male ratio
gender_user['male_ratio'] = gender_user['M']/gender_user['sums']
gender_user
sorted_by_gender_ratio = gender_user.sort_values(by = ['male_ratio'])

sorted_by_gender_ratio
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-add19425237f> in <module>
#       1 # calculate male ratio
# ----> 2 gender_user['male_ratio'] = gender_user['M']/gender_user['sums']
#       3 gender_user
#       4 sorted_by_gender_ratio = gender_user.sort_values(by = ['male_ratio'])
#       5
#
# NameError: name 'gender_user' is not defined

# %%
user_by_age = users.groupby('occupation')['age']

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').aggregate({'age': ['min', 'max']})
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...
